# %%
import requests
import pandas as pd
import re
from bs4 import BeautifulSoup


import os
from pandas.io.json import json_normalize
import urllib.request as request
import json

import operator
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %%
href = "https://chandrakantha.com/music-and-dance/film-and-pop/film-songs-rags/"
with request.urlopen(href) as response:
    d_source = response.read()

# %%
r_d = d_source.decode(encoding='UTF-8')
link_data = r_d.split('<a href="https://chandrakantha.com/raga_raag/film_song_raga/')[1:]

# %% [markdown]
# #### link corresponding to each raga

# %%
raga_list = []
for i in link_data:
    if " (" in i:
        raga_list.append("https://chandrakantha.com/raga_raag/film_song_raga/" + i.split(">")[1].split("</a></li><li>")[0].split("</a")[0].split(" (")[0].replace(" ", "_").lower() + ".shtml")
    else:
        raga_list.append("https://chandrakantha.com/raga_raag/film_song_raga/" +i.split(">")[1].split("</a></li><li>")[0].split("</a")[0].replace(" ", "_").lower() + ".shtml")
raga_list
# Out:
# ['https://chandrakantha.com/raga_raag/film_song_raga/abhogi_kanada.shtml',
#  'https://chandrakantha.com/raga_raag/film_song_raga/adana.shtml',
#  'https://chandrakantha.com/raga_raag/film_song_raga/ahir_bhairav.shtml',
#  'https://chandrakantha.com/raga_raag/film_song_raga/alhiya_bilawal.shtml',
#  'https://chandrakantha.com/raga_raag/film_song_raga/anandbhairavi.shtml',
#  'https://chandrakantha.com/raga_raag/film_song_raga/nand.shtml',
#  'https://chandrakantha.com/raga_raag/film_song_raga/nand.shtml',
#  'https://chandrakantha.com/raga_raag/film_song_raga/asavari.shtml',
#  'https://chandrakantha.com/raga_raag/film_song_raga/audav_bilawal.shtml',
#  'https://chandrakantha.com/raga_raag/film_song_raga/audav_devgiri.shtml',
#  'https://chandrakantha.com/raga_raag/film_song_raga/bageshri.shtml',
#  'https://chandrakantha.com/raga_raag/film_song_raga/bahar.shtml',
#  'https://chandrakantha.com/raga_raag/film_song_raga/barawa.shtml',
# ...

# %%
link_separate = ["https://chandrakantha.com/raga_raag/film_song_raga/audav_bilawal.shtml", 
                 "https://chandrakantha.com/raga_raag/film_song_raga/audav_devgiri.shtml", 
                 "https://chandrakantha.com/raga_raag/film_song_raga/bhairavi.shtml",
                "https://chandrakantha.com/raga_raag/film_song_raga/bhavkauns/bhavkaush.shtml",
                "https://chandrakantha.com/raga_raag/film_song_raga/bhinashadaj.shtml",
                "https://chandrakantha.com/raga_raag/film_song_raga/bhimpalasi.shtml",
                "https://chandrakantha.com/raga_raag/film_song_raga/chandrakauns_/_chandrakaush.shtml",
                "https://chandrakantha.com/raga_raag/film_song_raga/deshkar.shtml",
                "https://chandrakantha.com/raga_raag/film_song_raga/hindoli.shtml",
                "https://chandrakantha.com/raga_raag/film_song_raga/jait_kalyan.shtml",
                "https://chandrakantha.com/raga_raag/film_song_raga/kalingada.shtml",
                "https://chandrakantha.com/raga_raag/film_song_raga/kalyan.shtml",
                "https://chandrakantha.com/raga_raag/film_song_raga/kaushikdhwani.shtml",
                "https://chandrakantha.com/raga_raag/film_song_raga/malkauns/malkaush.shtml",
                "https://chandrakantha.com/raga_raag/film_song_raga/pahadi.shtml",
                "https://chandrakantha.com/raga_raag/film_song_raga/sarang.shtml",
                "https://chandrakantha.com/raga_raag/film_song_raga/sindhu_bhairavi.shtml",
                "https://chandrakantha.com/raga_raag/film_song_raga/yaman_kalyan.shtml"]
song_name = []
film_name = []
raga_name = []
year=[]

for link in raga_list:
    print(link)
    if link not in link_separate:
        
    #if "audav_bilawal.shtml" in link:
    #    link = "https://chandrakantha.com/raga_raag/film_song_raga/bhinashadaj.shtml"
    #if "audav_devgiri.shtml" in link:
    #   link = "https://chandrakantha.com/raga_raag/film_song_raga/audav_devgiri.html"
    #if "audav_devgiri.shtml" in link:
    #    link = "https://chandrakantha.com/raga_raag/film_song_raga/bhairavi.html"
        with request.urlopen(link) as res:
            print(link)
            source_data = res.read()
        r_data = source_data.decode(encoding='UTF-8')
        data = r_data.split("<b>")[1:]
        data_set =[]
        for i in data:
            data_set.append(i.split(">"))

        for i in data_set:
            for j in i:
                if "</b" in j:
                    song_name.append(j.split("</b")[0])
                if "\nFilm" in j:
                    film_name.append(j.split("\nFilm - ")[1].split("<br")[0])
                if "\nRag" in j:
                    raga_name.append(j.split("\nRag - ")[1].split("<br")[0]) 
                #if "\nYear" in j:
                 #   year.append(j.split("\nYear")[1])
# Out:
# https://chandrakantha.com/raga_raag/film_song_raga/abhogi_kanada.shtml
# https://chandrakantha.com/raga_raag/film_song_raga/abhogi_kanada.shtml
# https://chandrakantha.com/raga_raag/film_song_raga/adana.shtml
# https://chandrakantha.com/raga_raag/film_song_raga/adana.shtml
# https://chandrakantha.com/raga_raag/film_song_raga/ahir_bhairav.shtml
# https://chandrakantha.com/raga_raag/film_song_raga/ahir_bhairav.shtml
# https://chandrakantha.com/raga_raag/film_song_raga/alhiya_bilawal.shtml
# https://chandrakantha.com/raga_raag/film_song_raga/alhiya_bilawal.shtml
# https://chandrakantha.com/raga_raag/film_song_raga/anandbhairavi.shtml
# https://chandrakantha.com/raga_raag/film_song_raga/anandbhairavi.shtml
# https://chandrakantha.com/raga_raag/film_song_raga/nand.shtml
# https://chandrakantha.com/raga_raag/film_song_raga/nand.shtml
# https://chandrakantha.com/raga_raag/film_song_raga/nand.shtml
# https://chandrakantha.com/raga_raag/film_song_raga/nand.shtml
# ...

# %%
print(len(film_name))
print(len(song_name))
print(len(raga_name))
# Out:
# 495
# 590
# 495

# %%
remove_elements = ["\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n", "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n", "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n","NOTE"]
for i in song_name:
    if i in remove_elements:
        song_name.remove(i)

# %%
len(song_name)
# Out:
# 495

# %%
with request.urlopen("https://chandrakantha.com/raga_raag/film_song_raga/bhimpalasi.shtml") as res:
    source_data = res.read()

# %%
link_separate
# Out:
# ['https://chandrakantha.com/raga_raag/film_song_raga/audav_bilawal.shtml',
#  'https://chandrakantha.com/raga_raag/film_song_raga/audav_devgiri.shtml',
#  'https://chandrakantha.com/raga_raag/film_song_raga/bhairavi.shtml',
#  'https://chandrakantha.com/raga_raag/film_song_raga/bhavkauns/bhavkaush.shtml',
#  'https://chandrakantha.com/raga_raag/film_song_raga/bhinashadaj.shtml',
#  'https://chandrakantha.com/raga_raag/film_song_raga/bhimpalasi.shtml',
#  'https://chandrakantha.com/raga_raag/film_song_raga/chandrakauns_/_chandrakaush.shtml',
#  'https://chandrakantha.com/raga_raag/film_song_raga/deshkar.shtml',
#  'https://chandrakantha.com/raga_raag/film_song_raga/hindoli.shtml',
#  'https://chandrakantha.com/raga_raag/film_song_raga/jait_kalyan.shtml',
#  'https://chandrakantha.com/raga_raag/film_song_raga/kalingada.shtml',
#  'https://chandrakantha.com/raga_raag/film_song_raga/kalyan.shtml',
#  'https://chandrakantha.com/raga_raag/film_song_raga/kaushikdhwani.shtml',
# ...

# %%
list_new = ["https://chandrakantha.com/raga_raag/film_song_raga/bhinashadaj.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/kalyan1.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/kalyan1D.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/kalyan2.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/kalyan2K.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/kalyan2M.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/kalyan2P.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/kalyan3.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/kalyan3T.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/kalyan3Y.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/bhairavi_2.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/bhairavi_3.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/pahadi1.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/pahadi1b.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/pahadi1c.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/pahadi2.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/pahadi2b.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/pahadi3.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/pahadi3b.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/pahadi3b.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/bhairavi_1.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/bhairavi_1B.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/bhairavi_1C.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/bhairavi_1D.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/bhairavi_1E.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/bhairavi_1FGH.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/bhairavi_1I.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/bhairavi_2.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/bhairavi_2K.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/bhairavi_2L.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/bhairavi_2M.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/bhairavi_3.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/bhairavi_3QR.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/bhairavi_3S.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/bhairavi_3TU.shtml",
            "https://chandrakantha.com/raga_raag/film_song_raga/bhairavi_3VWXYZ.shtml"]

song_name_1 = []
film_name_1 = []
raga_name_1 = []
#ear=[]

for link in list_new:
    print(link)
    
    with request.urlopen(link) as res_1:
        print(link)
        source_data_1 = res_1.read()
    r_data_1 = source_data_1.decode(encoding='UTF-8')
    data_1 = r_data_1.split("<b>")[1:]
    data_set_1 =[]
    for i in data_1:
        data_set_1.append(i.split(">"))

    for i in data_set_1:
        for j in i:
            if "</b" in j:
                song_name_1.append(j.split("</b")[0])
            if "\nFilm" in j:
                film_name_1.append(j.split("\nFilm - ")[1].split("<br")[0])
            if "\nRag" in j:
                raga_name_1.append(j.split("\nRag - ")[1].split("<br")[0]) 
                #if "\nYear" in j:
                 #   year.append(j.split("\nYear")[1])
# Out:
# https://chandrakantha.com/raga_raag/film_song_raga/bhinashadaj.shtml
# https://chandrakantha.com/raga_raag/film_song_raga/bhinashadaj.shtml
# https://chandrakantha.com/raga_raag/film_song_raga/kalyan1.shtml
# https://chandrakantha.com/raga_raag/film_song_raga/kalyan1.shtml
# https://chandrakantha.com/raga_raag/film_song_raga/kalyan1D.shtml
# https://chandrakantha.com/raga_raag/film_song_raga/kalyan1D.shtml
# https://chandrakantha.com/raga_raag/film_song_raga/kalyan2.shtml
# https://chandrakantha.com/raga_raag/film_song_raga/kalyan2.shtml
# https://chandrakantha.com/raga_raag/film_song_raga/kalyan2K.shtml
# https://chandrakantha.com/raga_raag/film_song_raga/kalyan2K.shtml
# https://chandrakantha.com/raga_raag/film_song_raga/kalyan2M.shtml
# https://chandrakantha.com/raga_raag/film_song_raga/kalyan2M.shtml
# https://chandrakantha.com/raga_raag/film_song_raga/kalyan2P.shtml
# https://chandrakantha.com/raga_raag/film_song_raga/kalyan2P.shtml
# ...

# %%
for i in song_name_1:
    if i in remove_elements:
        song_name_1.remove(i)

# %%
rm_elem = ["A-C", "D-H", "I-J", "K-L", "M-O", "P-R", "S", "T-X", "Y-Z", "J", "N,O,P", "A-B", "C-J", "H-I", "J-K", "L-P", 
           "Q-T", "U-Z", "A", "B","C", "D", "E", "F,G,H","I", "J", "K", "L", "M", "T,U", "V,W,X,Y", "C-G", "Q,R"]
for i in song_name_1:
    if i in rm_elem:
        song_name_1.remove(i)

# %%
print(len(song_name_1), len(film_name_1), len(raga_name_1))
# Out:
# 327 327 327

# %%
song_name.extend(song_name_1)

# %%
len(song_name)
# Out:
# 822

# %%
film_name.extend(film_name_1)

# %%
len(film_name)
# Out:
# 822

# %%
raga_name.extend(raga_name_1)

# %%
len(raga_name)
# Out:
# 822

# %%
raga_name_=[]
for i in raga_name:
    if "<a href" in i:
        _d1 = i.split("/")
        if "html" in _d1[-1]:
            raga_name_.append(_d1[-1].split(".html")[0])
    else:
        raga_name_.append(i)
raga_name_
# Out:
# ['Abhogi Kanada',
#  'Abhogi Kanada',
#  'Adana',
#  'Adana',
#  'Adana',
#  'Adana',
#  'Adana',
#  'Adana',
#  'ahir_bhairav',
#  'ahir_bhairav',
#  'ahir_bhairav',
#  'ahir_bhairav',
#  'ahir_bhairav',
#  'ahir_bhairav',
#  'ahir_bhairav',
#  'ahir_bhairav',
#  'ahir_bhairav',
#  'ahir_bhairav',
#  'ahir_bhairav',
#  'ahir_bhairav',
#  'ahir_bhairav',
#  'ahir_bhairav',
#  'ahir_bhairav',
#  'Alhiya Bilawal',
#  'Alhiya Bilawal',
#  'Alhiya Bilawal',
#  'Anandbhairavi',
#  'Anandbhairavi',
#  'Nand',
#  'Nand',
#  'asawari',
#  'asawari',
#  'asawari',
#  'asawari',
#  'asawari',
#  'Bageshri',
#  'Bageshri',
#  'Bageshri',
#  'Bageshri',
#  'Bageshri',
#  'Bageshri',
#  'Bageshri',
#  'Bageshri',
#  'Bageshri',
#  'Bageshri',
#  'Bageshri',
#  'Bageshri',
#  'Bageshri',
#  'Bageshri',
#  'Bageshri',
#  'Bageshree',
#  'Bageshri',
#  'Bageshri',
#  'Bahar',
#  'Bahar',
#  'Bahar',
#  'Bahar',
#  'Barawa',
#  'Basant',
#  'Basant',
#  'Basant Bahar',
#  'Basant Mukhari',
# ...

# %%
df= pd.DataFrame(list(zip(film_name, song_name, raga_name_)), columns =['Film', 'Song', 'Raga'])
df
# Out:
#                                           Film  \
# 0                                 Kagaz ki Nau
# 1    Kshudista Pashan (Bengali)(Hungry Stones)
# 2                                       Anpadh
# 3                                        Arzoo
# 4                    Jhanak Jhanak Paayel Baje
# ..                                         ...
# 817                           Saanj Aur Savera
# 818                            (non-film song)
# 819                                      Shair
# 820                        Hariyali Aur Raasta
# 821                                       Mela
#
#                                                   Song           Raga
# 0                       Na Jaiyo Re Sautan Ghar Sainya  Abhogi Kanada
# 1                                               Tarana  Abhogi Kanada
# 2                             Aap Ki Nazaron Ne Samjha          Adana
# 3                      Ai Dil Mujhe Aisi Jagah Le Chal          Adana
# ...

# %%
df.to_csv("Bollywood_and_ragas.csv")
